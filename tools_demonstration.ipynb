# %%
# %%capture
# %run Preparation_for_future_project.ipynb import *

from lookup_gene import *
from differential_expression import *
from find_targets import *
from plotting_functions import *

# %% [markdown]
# ## differential_expression tools

# %%
diff_expression(gene='Cd44', cluster1='6_TREAT', cluster2='0_TREAT')
# Finds difference in proportion of cells that express gene between two clusters
# Out:
# 0.07144184318097363

# %%
diff_exp_treat_6_0 = most_diff_exp(cluster1='6_TREAT', cluster2='0_TREAT', n_keep=100, df=data_treat)
diff_exp_treat_6_0
#     '''Finds most differentially expressed genes between two clsuters

#         - Returns tuple:
#             - return[0] is dict whose keys are genes and values are differences in expression
#             for gene between two clusters
#             - return[1] is list of genes that caused a ValueError
#             '''
# Out:
# The most differentially expressed genes are:
# {'Mki67': 0.9637681159420289,
#  'Smc2': 0.9396135265700483,
#  'Top2a': 0.8952991452991453,
#  'Phgdh': 0.8292456335934597,
#  'Birc5': 0.761984392419175,
#  'Fasn': 0.7511148272017838,
#  'Cdk1': 0.7511148272017838,
#  'Cenpa': 0.7486993682645857,
#  'Dkc1': 0.7076365663322185,
#  'Nasp': 0.7012263099219621,
#  'Hmmr': 0.6923076923076923,
#  'Ryk': 0.6898922333704942,
#  'Hmgb3': 0.6874767744332961,
#  'Cenpf': 0.6862690449646971,
#  'Trmt10c': 0.6798587885544408,
#  'Cdc20': 0.679022668153103,
#  'Uck2': 0.6693608324043107,
#  'Mad2l1': 0.6621144555927164,
#  'Mpp6': 0.6569119286510592,
#  'Ptprs': 0.6524526198439242,
#  'Dut': 0.6512448903753252,
#  'Gart': 0.650873281308064,
#  'Tpx2': 0.646413972500929,
#  'Ide': 0.6424191750278707,
#  'Mrps6': 0.6387959866220736,
#  'Rrs1': 0.6351727982162765,
#  'Rrm1': 0.6307134894091415,
#  'Stmn1': 0.6270903010033445,
#  'Tex30': 0.6258825715347455,
#  'Ttc39c': 0.6218877740616872,
#  'Dtymk': 0.617056856187291,
#  'Aspm': 0.6141768859160164,
#  'Ccnb1': 0.6117614269788183,
#  'Ube2c': 0.6093459680416202,
#  'Naa15': 0.6086027499070978,
#  'Ncbp1': 0.6077666295057599,
#  'Nedd4': 0.6069305091044221,
#  'Ncapd2': 0.6057227796358231,
#  'Rad21': 0.6046079524340394,
#  'Pold2': 0.6041434410999629,
#  'Rcn1': 0.6020995912300261,
#  'Tcf3': 0.5953177257525084,
#  'Hells': 0.5948532144184319,
#  'Alad': 0.5944816053511706,
#  'Tpm1': 0.5908584169453734,
#  'Anp32e': 0.5904868078781123,
#  'Zc3h14': 0.5880713489409142,
#  'Cad': 0.5876068376068376,
#  'Mcm7': 0.5863991081382386,
#  'Cks2': 0.5856558900037161,
#  'Kcnq1ot1': 0.5851913786696396,
#  'Sept1': 0.5851913786696396,
#  'Ybx3': 0.5837049424005947,
#  'Impad1': 0.5824043106651802,
#  'Psat1': 0.5803604607952434,
#  'Tacc3': 0.5803604607952434,
#  'Cks1b': 0.5779450018580454,
#  'Trap1': 0.5772017837235229,
#  'Cdca8': 0.5767372723894464,
#  'Bri3bp': 0.5763656633221851,
#  'Hirip3': 0.5743218134522483,
#  'Prep': 0.573950204384987,
#  'Gspt1': 0.5719992567818655,
#  'Myc': 0.5719063545150502,
#  'Psip1': 0.5680044593088072,
#  'Abce1': 0.5679115570419918,
#  'Gar1': 0.5667038275733928,
#  'Gnl3': 0.5654960981047937,
#  'Smc4': 0.5642883686361947,
#  'Hmgn1': 0.5627090301003345,
#  'Ubr5': 0.5615013006317354,
#  'Cbx5': 0.5610367892976589,
#  'Yars': 0.5606651802303976,
#  'Nrf1': 0.5594574507617985,
#  'Thop1': 0.5586213303604608,
#  '2410002F23Rik': 0.5562058714232627,
#  'Rbm33': 0.5510033444816054,
#  'Tipin': 0.5501672240802676,
#  'Rwdd4a': 0.5497956150130063,
#  'Slc1a5': 0.5477517651430696,
#  'Lbr': 0.5465440356744705,
#  'Ing1': 0.5461724266072092,
#  'Cers5': 0.5449646971386102,
#  'Strap': 0.5414344109996285,
#  'Thoc1': 0.5413415087328131,
#  'Ube3a': 0.5409698996655519,
#  'Zfp664': 0.5405053883314753,
#  'Usp10': 0.5392976588628763,
#  'Plk1': 0.5372538089929394,
#  'Rrm2': 0.5360460795243404,
#  'Serpinf1': 0.5360460795243404,
#  'Wdr75': 0.5356744704570792,
#  'Plod2': 0.5348383500557413,
#  'Ncapg': 0.5348383500557413,
#  'Ccna2': 0.5348383500557413,
#  'Tsfm': 0.5340951319212188,
#  'Usp14': 0.5337235228539576,
#  'Kif20a': 0.5336306205871423,
#  'Cfap298': 0.532051282051282,
#  'Pcbp4': 0.5312151616499442}

# %%
compare_to_rest(cluster1='6_TREAT', cluster2='0_TREAT', thresh=0.35, n_keep=50)
#     '''Returns dict - keys are genes that are differentially expressed between cluster1
#         and cluster2, and are not expressed greater than 'thresh' in any other cluster,
#         and keys are expression levels'''
# Out:
# The list of genes that are differentialy expressed between cluster 6_TREAT and cluster 0_TREAT, that are not expressed in more than 0.35 of any other cluster, are:
# {}

# %%
compare_treat_ctrl(diff_exp_treat_6_0, cluster_num=6)
#     '''Compares expression of genes in treat and control of same cluster
#         - Returns dict: keys are genes, values are list of statistical information'''
# Out:
# {'Mki67': {'CTRL Median': 4.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': 0.09399224806201545},
#  'Smc2': {'CTRL Median': 3.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': 0.11627906976744184},
#  'Top2a': {'CTRL Median': 7.0,
#   'Median effect': -5.5,
#   'Pct of cells effect': -0.02847346451997612},
#  'Phgdh': {'CTRL Median': 6.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.12380739415623132},
#  'Birc5': {'CTRL Median': 5.0,
#   'Median effect': -0.5,
#   'Pct of cells effect': -0.18135062611806796},
#  'Fasn': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.08512224209898633},
#  'Cdk1': {'CTRL Median': 4.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.12805605247465712},
#  'Cenpa': {'CTRL Median': 6.0,
#   'Median effect': -3.0,
#   'Pct of cells effect': -0.13774597495527718},
#  'Dkc1': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': 0.07252534287418011},
#  'Nasp': {'CTRL Median': 3.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.04144305307096008},
#  'Hmmr': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.13901311866428145},
#  'Ryk': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.0799791293977341},
#  'Hmgb3': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.14683959451401318},
#  'Cenpf': {'CTRL Median': 3.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.11680083482409065},
#  'Trmt10c': {'CTRL Median': 1.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.15004472271914138},
#  'Cdc20': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': 0.04017590936195581},
#  'Uck2': {'CTRL Median': 3.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': -0.18366129994036973},
#  'Mad2l1': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.10032796660703636},
#  'Mpp6': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.0017889087656529634},
#  'Ptprs': {'CTRL Median': 1.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': 0.24754025044722716},
#  'Dut': {'CTRL Median': 3.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': -0.16137447823494333},
#  'Gart': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': 0.10450208706022668},
#  'Tpx2': {'CTRL Median': 3.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.16234347048300535},
#  'Ide': {'CTRL Median': 2.0,
#   'Median effect': -0.5,
#   'Pct of cells effect': 0.17911449016100178},
#  'Mrps6': {'CTRL Median': 6.0,
#   'Median effect': -4.0,
#   'Pct of cells effect': -0.18038163387000594},
#  'Rrs1': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.019528920691711305},
#  'Rrm1': {'CTRL Median': 3.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.1545915324985092},
#  'Stmn1': {'CTRL Median': 13.0,
#   'Median effect': -10.0,
#   'Pct of cells effect': -0.2970333929636255},
#  'Tex30': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': -0.01990161001788915},
#  'Ttc39c': {'CTRL Median': 1.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.505664877757901},
#  'Dtymk': {'CTRL Median': 3.0,
#   'Median effect': -1.5,
#   'Pct of cells effect': -0.0989862850327966},
#  'Aspm': {'CTRL Median': 1.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.15123732856291},
#  'Ccnb1': {'CTRL Median': 3.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.1762820512820512},
#  'Ube2c': {'CTRL Median': 10.0,
#   'Median effect': -4.5,
#   'Pct of cells effect': -0.3216308884913536},
#  'Naa15': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.15488968395945146},
#  'Ncbp1': {'CTRL Median': 1.0,
#   'Median effect': 2.0,
#   'Pct of cells effect': 0.038237924865831774},
#  'Nedd4': {'CTRL Median': 4.0,
#   'Median effect': -1.5,
#   'Pct of cells effect': -0.31969290399522954},
#  'Ncapd2': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.14430530709600475},
#  'Rad21': {'CTRL Median': 3.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.04435002981514613},
#  'Pold2': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.047927847346451946},
#  'Rcn1': {'CTRL Median': 2.0,
#   'Median effect': -0.5,
#   'Pct of cells effect': -0.22957662492546205},
#  'Tcf3': {'CTRL Median': 4.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.183288610614192},
#  'Hells': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': -0.17337507453786516},
#  'Alad': {'CTRL Median': 1.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': 0.14288908765652952},
#  'Tpm1': {'CTRL Median': 11.0,
#   'Median effect': -9.0,
#   'Pct of cells effect': -0.29897137745974955},
#  'Anp32e': {'CTRL Median': 5.0,
#   'Median effect': -2.5,
#   'Pct of cells effect': -0.183288610614192},
#  'Zc3h14': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.057319618366129976},
#  'Cad': {'CTRL Median': 1.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': 0.04949314251639836},
#  'Mcm7': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': -0.19953786523553962},
#  'Cks2': {'CTRL Median': 7.0,
#   'Median effect': -2.5,
#   'Pct of cells effect': -0.19976147883124618},
#  'Kcnq1ot1': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.009615384615384581},
#  'Sept1': {'CTRL Median': 1.0,
#   'Median effect': 0.5,
#   'Pct of cells effect': 0.45550089445438285},
#  'Ybx3': {'CTRL Median': 8.0,
#   'Median effect': -3.5,
#   'Pct of cells effect': -0.06045020870602258},
#  'Impad1': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.05866129994036973},
#  'Psat1': {'CTRL Median': 2.0,
#   'Median effect': 2.5,
#   'Pct of cells effect': -0.09101073345259392},
#  'Tacc3': {'CTRL Median': 3.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.25767740011926055},
#  'Cks1b': {'CTRL Median': 8.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.3691115086463923},
#  'Trap1': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': 0.09675014907573054},
#  'Cdca8': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': -0.2489564698867024},
#  'Bri3bp': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': -0.14877757901013722},
#  'Hirip3': {'CTRL Median': 1.0,
#   'Median effect': 0.5,
#   'Pct of cells effect': 0.015578413834227867},
#  'Prep': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': 0.13416815742397137},
#  'Gspt1': {'CTRL Median': 3.0,
#   'Median effect': 2.0,
#   'Pct of cells effect': -0.0201252236135957},
#  'Myc': {'CTRL Median': 2.0,
#   'Median effect': 0.5,
#   'Pct of cells effect': -0.09197972570065593},
#  'Psip1': {'CTRL Median': 5.0,
#   'Median effect': -3.0,
#   'Pct of cells effect': -0.05948121645796056},
#  'Abce1': {'CTRL Median': 2.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': -0.051878354203935606},
#  'Gar1': {'CTRL Median': 3.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.1594364937388193},
#  'Gnl3': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': 0.047927847346451946},
#  'Smc4': {'CTRL Median': 4.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.2107930828861062},
#  'Hmgn1': {'CTRL Median': 14.0,
#   'Median effect': -8.5,
#   'Pct of cells effect': -0.22495527728085862},
#  'Ubr5': {'CTRL Median': 1.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.17814549791293977},
#  'Cbx5': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.09876267143709005},
#  'Yars': {'CTRL Median': 1.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.08862552176505667},
#  'Nrf1': {'CTRL Median': 1.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': 0.2620751341681574},
#  'Thop1': {'CTRL Median': 1.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': -0.0386851520572451},
#  '2410002F23Rik': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.0018634466308884434},
#  'Rbm33': {'CTRL Median': 1.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': 0.2562611806797853},
#  'Tipin': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': -0.15011926058437686},
#  'Rwdd4a': {'CTRL Median': 1.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': 0.24075730471079304},
#  'Slc1a5': {'CTRL Median': 2.0,
#   'Median effect': -0.5,
#   'Pct of cells effect': -0.02705724508050089},
#  'Lbr': {'CTRL Median': 1.0,
#   'Median effect': 0.5,
#   'Pct of cells effect': 0.09600477042337507},
#  'Ing1': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.08676207513416823},
#  'Cers5': {'CTRL Median': 1.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.11866428145497909},
#  'Strap': {'CTRL Median': 4.0,
#   'Median effect': -2.5,
#   'Pct of cells effect': -0.013938580799045863},
#  'Thoc1': {'CTRL Median': 1.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.14967203339296364},
#  'Ube3a': {'CTRL Median': 2.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': 0.009540846750149101},
#  'Zfp664': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.1016696481812761},
#  'Usp10': {'CTRL Median': 1.0,
#   'Median effect': 0.5,
#   'Pct of cells effect': 0.016547406082289884},
#  'Plk1': {'CTRL Median': 3.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.19991055456171736},
#  'Rrm2': {'CTRL Median': 3.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.298747763864043},
#  'Serpinf1': {'CTRL Median': 6.0,
#   'Median effect': 2.0,
#   'Pct of cells effect': -0.39758497316636854},
#  'Wdr75': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': 0.0175163983303519},
#  'Plod2': {'CTRL Median': 3.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.368515205724508},
#  'Ncapg': {'CTRL Median': 1.0,
#   'Median effect': 0.0,
#   'Pct of cells effect': -0.015802027429934418},
#  'Ccna2': {'CTRL Median': 4.0,
#   'Median effect': -2.0,
#   'Pct of cells effect': -0.33460047704233753},
#  'Tsfm': {'CTRL Median': 2.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': 0.04986583184257598},
#  'Usp14': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.026311866428145425},
#  'Kif20a': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.010957066189624332},
#  'Cfap298': {'CTRL Median': 1.0,
#   'Median effect': 1.0,
#   'Pct of cells effect': 0.08922182468694095},
#  'Pcbp4': {'CTRL Median': 2.0,
#   'Median effect': -1.0,
#   'Pct of cells effect': -0.31328264758497315}}

# %% [markdown]
# ## find_target tools

# %%
# Genes expressed in GBM treatment group
gbm_genes = genes_expressed(cluster='6_TREAT')
gbm_genes
# Out:
# ['Mrpl15',
#  'Lypla1',
#  'Tcea1',
#  'Rgs20',
#  'Atp6v1h',
#  'Rb1cc1',
#  '4732440D04Rik',
#  'Pcmtd1',
#  'Rrs1',
#  '2610203C22Rik',
#  'Mybl1',
#  'Vcpip1',
#  'Sgk3',
#  'Snhg6',
#  'Cops5',
#  'Cspp1',
#  'Arfgef1',
#  'Slco5a1',
#  'Ncoa2',
#  'Tram1',
#  'Lactb2',
#  'Msc',
#  'Terf1',
#  'Rpl7',
#  'Rdh10',
#  'Stau2',
#  'Ube2w',
#  'Eloc',
#  'Tmem70',
#  'Ly96',
#  'Mcm3',
#  'Tram2',
#  'Tmem14a',
#  'Kcnq5',
#  'Ogfrl1',
#  'B3gat2',
#  'Smap1',
#  'Sdhaf4',
#  'Fam135a',
#  'Lmbrd1',
#  'Adgrb3',
#  'Phf3',
#  'Ptp4a1.1',
#  'Prim2',
#  'Rab23',
#  'Zfp451',
#  'Dst',
#  'Gm37233',
#  'Ccdc115',
#  'Imp4',
#  'Ptpn18',
#  'Gm28417',
#  'Fam168b',
#  'Plekhb2',
#  'Hs6st1',
#  'Uggt1',
#  'Neurl3',
#  'Arid5a',
#  'Kansl3',
#  'Lman2l',
#  'Cnnm4',
#  'Cnnm3',
#  'Ankrd23',
#  'Ankrd39',
#  'Sema4c',
#  'D430040D24Rik',
#  'Cox5b',
#  'Actr1b',
#  'Zap70',
#  'Tmem131',
#  'Gm38115',
#  'Inpp4a',
#  'Coa5',
#  'Unc50',
#  'Mgat4a',
#  'Tsga10',
#  'Lipt1',
#  'Mitd1',
#  'Mrpl30',
#  'Txndc9',
#  'Eif5b',
#  'Rev1',
#  'Chst10',
#  'Pdcl3',
#  'Rpl31',
#  'Cnot11',
#  'Rnf149',
#  'Map4k4',
#  'Il1r2',
#  'Il1r1',
#  'Il1rl1',
#  'Il18r1',
#  'Il18rap',
#  'Gm37915',
#  'Pou3f3',
#  'Mrps9',
#  'Tgfbrap1',
#  'AI597479',
#  'Fhl2',
#  'Nck2',
#  'Uxs1',
#  'Tpp2',
#  'Gm8251',
#  'Tex30',
#  'Poglut2',
#  'Bivm',
#  'Ercc5',
#  'Gulp1',
#  'Col3a1',
#  'Col5a2',
#  'Wdr75',
#  'Dnah7b',
#  'Slc39a10',
#  'Cavin2',
#  'Nabp1',
#  'Stat4',
#  'Stat1',
#  'Gls',
#  'Nab1',
#  'Nemp2',
#  'Mfsd6',
#  'Inpp1',
#  'Hibch',
#  'Pms1',
#  'Ormdl1',
#  'Osgepl1',
#  'Asnsd1',
#  'Stk17b',
#  'Gtf3c3',
#  'Ankrd44',
#  'Sf3b1',
#  'Coq10b',
#  'Hspd1',
#  'Hspe1',
#  'Mob4',
#  'Rftn2',
#  'Mars2',
#  'Satb2',
#  '1700066M21Rik',
#  'Tyw5',
#  'Maip1',
#  'Kctd18',
#  'Sgo2a',
#  'Bzw1',
#  'Clk1',
#  'Ppil3',
#  'Nif3l1',
#  'Orc2',
#  'Gm15834',
#  'Fam126b',
#  'Ndufb3',
#  'Cflar',
#  'Casp8',
#  'Trak2',
#  'Tmem237',
#  'Als2',
#  'Fzd7',
#  'Sumo1',
#  'Nop58',
#  'Bmpr2',
#  'Fam117b',
#  'Ica1l',
#  'Wdr12',
#  'Carf',
#  'Nbeal1',
#  'Cyp20a1',
#  'Abi2',
#  'Raph1',
#  'Cd28',
#  'Ctla4',
#  'Icos',
#  'Nrp2',
#  'Ino80d',
#  'Ino80dos',
#  'Ndufs1',
#  'Eef1b2',
#  'Fastkd2',
#  'Klf7',
#  'Creb1',
#  'Mettl21a',
#  '2810408I11Rik',
#  'Ccnyl1',
#  'Fzd5',
#  'Plekhm3',
#  'Idh1',
#  'Pikfyve',
#  'Map2',
#  'Unc80',
#  'Rpe',
#  'Kansl1l',
#  'Acadl',
#  'Lancl1',
#  'Ikzf2',
#  'Bard1',
#  'Atic',
#  'Fn1',
#  'Pecr',
#  'Xrcc5',
#  'Smarcal1',
#  'Rpl37a',
#  'Igfbp2',
#  'Arpc2',
#  'Aamp',
#  'Pnkd',
#  'Tmbim1',
#  'Slc11a1',
#  'Ctdsp1',
#  'Usp37',
#  'Cnot9',
#  'Zfp142',
#  'Bcs1l',
#  'Rnf25',
#  'Stk36',
#  'Ttll4',
#  'Wnt6',
#  'Cnppd1',
#  'Retreg2',
#  'Zfand2b',
#  'Atg9a',
#  'Ankzf1',
#  'Stk16',
#  'Tuba4a',
#  'Ptprn',
#  'Dnpep',
#  'Gmppa',
#  'Chpf',
#  'Obsl1',
#  'Stk11ip',
#  'Farsb',
#  'Acsl3',
#  'Ap1s3',
#  'Wdfy1',
#  'Mrpl44',
#  'Serpine2',
#  'Fam124b',
#  'Cul3',
#  'Dock10',
#  'Rhbdd1',
#  'Mff',
#  'Agfg1',
#  'Pid1',
#  'Trip12',
#  'A530032D15Rik',
#  'A530040E14Rik',
#  'Sp110',
#  'Sp140',
#  'Sp100',
#  'A630001G21Rik',
#  'Cab39',
#  'Itm2c',
#  'Gpr55',
#  'Psmd1',
#  'Armc9',
#  'Ncl',
#  'Ptma',
#  'Pde6d',
#  'Cops7b',
#  'Dis3l2',
#  'Eif4e2',
#  'Gigyf2',
#  'Inpp5d',
#  'Atg16l1',
#  'Dgkd',
#  'Usp40',
#  'Ugt1a7c',
#  'Mroh2a',
#  'Hjurp',
#  'Arl4c',
#  'Sh3bp4',
#  'Agap1',
#  'Ackr3',
#  'Cops8',
#  'Lrrfip1',
#  'Ramp1',
#  'Ube2f',
#  'Scly',
#  'Ilkap',
#  'Hes6',
#  'Per2',
#  'Traf3ip1',
#  'Twist2',
#  'Hdac4',
#  'Ndufa10',
#  'Cops9',
#  'Gpc1',
#  'Dusp28',
#  'Rnpepl1',
#  '9430060I03Rik',
#  'Capn10',
#  'Gpr35',
#  'Kif1a',
#  'Mterf4',
#  'Pask',
#  'Ppp1r7',
#  'Hdlbp',
#  'Sept2',
#  'Stk25',
#  'Bok',
#  'Thap4',
#  'Atg4b',
#  'Dtymk',
#  'Ing5',
#  'D2hgdh',
#  'Pdcd1',
#  'Fam174a',
#  'St8sia4',
#  'D1Ertd622e',
#  'Ppip5k2',
#  'Gin1',
#  'Pam',
#  'B230216N24Rik',
#  'Cdh20',
#  'Pign',
#  'Relch',
#  'Gm7160',
#  'Zcchc2',
#  'Phlpp1',
#  'Bcl2',
#  'Kdsr',
#  'Vps4b',
#  'Serpinb8',
#  'Dsel',
#  'Tsn',
#  'Nifk',
#  'Clasp1',
#  'Ralb',
#  'Tmem185b',
#  'Epb41l5',
#  'Ptpn4',
#  'Tmem177',
#  'Tmem37',
#  'Dbi',
#  '3110009E18Rik',
#  'En1',
#  'Insig2',
#  'Ccdc93',
#  'Ddx18',
#  'Actr3',
#  'Slc35f5',
#  'Lypd1',
#  'Nckap5',
#  'Mgat5',
#  'Tmem163',
#  '2900009J06Rik',
#  'Ccnt2',
#  'Rab3gap1',
#  'Zranb3',
#  'R3hdm1',
#  'Ubxn4',
#  'Mcm6',
#  'Dars',
#  'Pfkfb2',
#  'Yod1',
#  'Fcmr',
#  'Il10',
#  'Mapkapk2',
#  'Dyrk3',
#  'Eif2d',
#  'Rassf5',
#  'Ikbke',
#  'Srgap2',
#  'Fam72a',
#  'Rab7b',
#  'Slc41a1',
#  'Rab29',
#  'Nucks1',
#  'Elk4',
#  'Klhdc8a',
#  'Nuak2',
#  'Tmcc2',
#  'Dstyk',
#  'Rbbp5',
#  'Nfasc',
#  'Mdm4',
#  'Ppp1r15b',
#  'Snrpe',
#  'Gm38394',
#  'Lax1',
#  'Atp2b4',
#  'Btg2',
#  'Tmem183a',
#  'Cyb5r1',
#  'Adipor1',
#  'Klhl12',
#  'Rabif',
#  'Kdm5b',
#  'Ppp1r12b',
#  'Ube2t',
#  'Lgr6',
#  'Ptpn7',
#  'Arl8a',
#  'Gpr37l1',
#  'Rnpep',
#  'Timm17a',
#  'Shisa4',
#  'Ipo9',
#  'Nav1',
#  'Csrp1',
#  'Phlda3',
#  'Tnnt2',
#  'Tmem9',
#  'Kif21b',
#  'Inava',
#  'Gpr25',
#  'Camsap2',
#  'Ddx59',
#  'Kif14',
#  'Zfp281',
#  'Gm19705',
#  'Gm4258',
#  'Ptprc',
#  'Nek7',
#  '2310009B15Rik',
#  'Dennd1b',
#  'Zbtb41',
#  'Aspm',
#  'Cdc73',
#  'Glrx2',
#  'Ro60',
#  'Uchl5',
#  'Gm29170',
#  'Rgs2',
#  'Rgs1',
#  'Pla2g4a',
#  'Ptgs2',
#  'Ptgs2os2',
#  'Odr4',
#  'Tpr',
#  'Ivns1abp',
#  'Swt1',
#  'Trmt1l',
#  'Rnf2',
#  'Fam129a',
#  'Edem3',
#  '1700025G04Rik',
#  'Tsen15',
#  'Rgl1',
#  'Arpc5',
#  'Ncf2',
#  'Smg7',
#  'Gm28791',
#  'Nmnat2',
#  'Lamc2',
#  'Lamc1',
#  'Dhx9',
#  'Rgs16',
#  'Glul',
#  'Ier5',
#  'Mr1',
#  'Stx6',
#  'Xpr1',
#  'Acbd6',
#  'Qsox1',
#  'Cep350',
#  'Tor1aip1',
#  'Tor1aip2',
#  'Gm2000',
#  'Soat1',
#  'Abl2',
#  'Tor3a',
#  'Fam20b',
#  'Ralgps2',
#  'Rasal2',
#  'Cryzl2',
#  'Cop1',
#  'Tnr',
#  '4930523C07Rik',
#  'Mrps14',
#  'Cacybp',
#  'Rabgap1l',
#  'Rc3h1',
#  'Zbtb37',
#  'Gas5',
#  'Dars2',
#  'Cenpl',
#  'Klhl20',
#  'Prdx6',
#  'Fasl',
#  'Suco',
#  'Pigc',
#  'Dnm3',
#  'Dnm3os',
#  'Eef1aknmt',
#  'Vamp4',
#  'Prrc2c',
#  'Prrx1',
#  'Gorab',
#  'Scyl3',
#  'Sell',
#  'Slc19a2',
#  'Blzf1',
#  'Sft2d2',
#  'Tiprl',
#  'Gm38190',
#  'Mpc2',
#  'Mpzl1',
#  'Rcsd1',
#  'Creg1',
#  'Gm16565',
#  'Cd247',
#  'Pou2f1',
#  'Gm15853',
#  'Tada1',
#  'Pogk',
#  'Uck2',
#  'Tmco1',
#  'Aldh9a1',
#  'Mgst3',
#  'Pbx1',
#  'Nuf2',
#  'Hsd17b7',
#  'Ddr2',
#  'Uap1',
#  'Uhmk1',
#  'Olfml2b',
#  'Atf6',
#  'Dusp12',
#  'Fcgr2b',
#  'Fcgr4',
#  'Fcgr3',
#  'Sdhc',
#  'Tomm40l',
#  'Fcer1g',
#  'Ndufs2',
#  'Adamts4',
#  'B4galt3',
#  'Ppox',
#  'Usp21',
#  'Ufc1',
#  'Gm20045',
#  'Dedd',
#  'Nit1',
#  'Pfdn2',
#  'Nectin4',
#  'Arhgap30',
#  'Usf1',
#  'B930036N10Rik',
#  'Ly9',
#  'Slamf7',
#  'Cd48',
#  'Slamf1',
#  'Cd84',
#  'Vangl2',
#  'Ncstn',
#  'Copa',
#  'Pex19',
#  'Dcaf8',
#  'Pea15a',
#  'Igsf8',
#  'Atp1a2',
#  'Pigm',
#  'Slamf9',
#  'Igsf9',
#  'Tagln2',
#  'Slamf8',
#  'Aim2',
#  'Ifi206',
#  'Ifi214',
#  'Ifi213',
#  'Ifi209',
#  'Ifi208',
#  'Ifi207',
#  'Ifi204',
#  'Mndal',
#  'Ifi211',
#  'Ifi203',
#  'Ifi205',
#  'Rgs7',
#  'Fh1',
#  'Kmo',
#  'Chml',
#  'Exo1',
#  'Cep170',
#  'Sdccag8',
#  'Akt3',
#  'Zbtb18',
#  'Adss',
#  'Desi2',
#  'Cox20',
#  'Hnrnpu',
#  'Kif26b',
#  'Smyd3',
#  'Tfb2m',
#  'Sccpdh',
#  'Ahctf1',
#  'Cdc42bpa',
#  'Psen2',
#  'Itpkb',
#  'Parp1',
#  'Acbd3',
#  'H3f3a',
#  'Sde2',
#  'Pycr2',
#  'Nvl',
#  'Cnih4',
#  'Wdr26',
#  'Lbr',
#  'Enah',
#  'Srp9',
#  'Degs1',
#  'Fbxo28',
#  'Trp53bp2',
#  'Capn2',
#  'Brox',
#  'Aida',
#  'Mia3',
#  'Taf1a',
#  'Dusp10',
#  '1700056E22Rik',
#  'Gm37800',
#  'Hlx',
#  'Marc2',
#  'Rab3gap2',
#  'Iars2',
#  'Bpnt1',
#  'Eprs',
#  'Rrp15',
#  'Gpatch2',
#  'Kctd3',
#  'Kcnk2',
#  'Cenpf',
#  'Ptpn14',
#  'Smyd2',
#  'Rps6kc1',
#  'Angel2',
#  'Vash2',
#  'Flvcr1',
#  'Tatdn3',
#  'Nsl1',
#  'Batf3',
#  'Atf3',
#  'Nenf',
#  'Pacc1',
#  'Ppp2r5a',
#  'Dtl',
#  'Ints7',
#  'Lpgat1',
#  'Nek2',
#  'Slc30a1',
#  'Gm26670',
#  'Traf5',
#  'Rcor3',
#  'Hhat',
#  'Utp25',
#  'Traf3ip3',
#  'Lamb3',
#  'Hsd11b1',
#  'Cr1l',
#  'Fam171a1',
#  'Nmt2',
#  'Rpp38',
#  'Acbd7',
#  'Dclre1c',
#  'Suv39h2',
#  'Hspa14',
#  'Gm45902',
#  'Fam107b',
#  'Frmd4a',
#  'Gm36988',
#  'Prpf18',
#  'Bend7',
#  'Sephs1',
#  'Phyh',
#  'Mcm10',
#  'Camk1d',
#  'Cdc123',
#  'Nudt5',
#  'Sec61a2',
#  'Upf2',
#  'Echdc3',
#  'Usp6nl',
#  'Celf2',
#  'Gata3',
#  'Taf3',
#  'Atp5c1',
#  'Kin',
#  'Prkcq',
#  'Pfkfb3',
#  'Rbm17',
#  'Il2ra',
#  'Il15ra',
#  'Fbh1',
#  'Ankrd16',
#  'Mindy3',
#  'C1ql3',
#  'Rsu1',
#  'Gm13270',
#  'Vim',
#  'Hacd1',
#  'Stam',
#  'Nsun6',
#  'Arl5b',
#  'Nebl',
#  'Mllt10',
#  'Dnajc1',
#  'Commd3',
#  'Bmi1',
#  'Pip4k2a',
#  'Armc3',
#  'Otud1',
#  'Arhgap21',
#  'Thnsl1',
#  'Apbb1ip',
#  'Pdss1',
#  'Abi1',
#  'Acbd5',
#  'Mastl',
#  'Yme1l1',
#  'Spopl',
#  'Il1rn',
#  'Psd4',
#  'Ehmt1',
#  'Arrdc1',
#  'Zmynd19',
#  'Dph7',
#  'Mrpl41',
#  'Pnpla7',
#  'Nsmf',
#  'Nrarp',
#  'Tor4a',
#  'Nelfb',
#  'Tubb4b',
#  'Ndor1',
#  'Tmem203',
#  'Tprn',
#  'Ssna1',
#  'Anapc2',
#  'Man1b1',
#  'Dpp7',
#  'Uap1l1',
#  'Sapcd2',
#  'Npdc1',
#  'Fut7',
#  'Abca2',
#  'Paxx',
#  'Fbxw5',
#  'Traf2',
#  'Edf1',
#  'Phpt1',
#  'Ajm1',
#  'Rabl6',
#  'Camsap1',
#  'Ubac1',
#  'Nacc2',
#  'Tmem250-ps',
#  'Qsox2',
#  'Gpsm1',
#  'Dnlz',
#  'Snapc4',
#  'Entr1',
#  'Pmpca',
#  'Inpp5e',
#  'Sec16a',
#  'Notch1',
#  'Egfl7',
#  'Dipk1b',
#  'Med22',
#  'Rpl7a',
#  'Surf1',
#  'Surf2',
#  'Surf4',
#  'Rexo4',
#  'Cacfd1',
#  'Slc2a6',
#  'Brd3os',
#  'Brd3',
#  'Wdr5',
#  'Rxra',
#  'Col5a1',
#  'Olfm1',
#  'Mrps2',
#  'Ralgds',
#  'Gtf3c5',
#  'Tsc1',
#  'Gtf3c4',
#  'Ddx31',
#  'Ttf1',
#  'Setx',
#  'Med27',
#  'Rapgef1',
#  'Trub2',
#  'Coq4',
#  'Urm1',
#  'Cercam',
#  'Odf2',
#  'Gle1',
#  'Sptan1',
#  'Wdr34',
#  'Set',
#  'Zdhhc12',
#  'Zer1',
#  'Tbc1d13',
#  'Endog',
#  'Spout1',
#  'Kyat1',
#  'Lrrc8a',
#  'Nup188',
#  'Sh3glb2',
#  'Dolpp1',
#  'Ptpa',
#  'Ier5l',
#  '1700001O22Rik',
#  'Ntmt1',
#  'Asb6',
#  'Ptges',
#  'Tor1b',
#  'Tor1a',
#  'BC005624',
#  'Fnbp1',
#  'D330023K18Rik',
#  'Gpr107',
#  'Ncs1',
#  'Ass1',
#  'Fubp3',
#  'Exosc2',
#  'Abl1',
#  'Nup214',
#  'Fam78a',
#  'Prrc2b',
#  'Pomt1',
#  'Uck1',
#  'Swi5',
#  'Golga2',
#  'Dnm1',
#  'Ciz1',
#  '1110008P14Rik',
#  'Lcn2',
#  'Slc25a25',
#  'Fam102a',
#  'Dpm2',
#  'St6galnac4',
#  'St6galnac6',
#  'Ak1',
#  'Eng',
#  'Fpgs',
#  'Cdk9',
#  'Sh2d3c',
#  'Tor2a',
#  'Ptrh1',
#  'Stxbp1',
#  'Fam129b',
#  'Lrsam1',
#  'Rpl12',
#  'Slc2a8',
#  'Ralgps1',
#  'Angptl2',
#  'Mvb12b',
#  'Pbx3',
#  'Mapkap1',
#  'Gapvd1',
#  'Hspa5',
#  'Rabepk',
#  'Fbxw2',
#  'Psmd5',
#  'Traf1',
#  'Cntrl',
#  'Rab14',
#  'Gsn',
#  'Ggta1',
#  'Dab2ip',
#  'Ndufa8',
#  'Rbm18',
#  'Mrrf',
#  'Pdcl',
#  'Rc3h2',
#  'Zbtb26',
#  'Rabgap1',
#  'Strbp',
#  'Crb2',
#  'Dennd1a',
#  'Lhx2',
#  'Nek6',
#  'Psmb7',
#  'Rpl35',
#  'Arpc5l',
#  'Scai',
#  'Ppp6c',
#  'Arhgap15',
#  'Gtdc1',
#  'Zeb2',
#  'Zeb2os',
#  'Acvr2a',
#  'Orc4',
#  'Mbd5',
#  'Epc2',
#  'Mmadhc',
#  'Rnd3',
#  'Rbm43',
#  'Nmi',
#  'Tnfaip6',
#  'Rif1',
#  'Neb',
#  'Arl5a',
#  'Stam2',
#  'Fmnl2',
#  'Prpf40a',
#  'Arl6ip6',
#  'Nr4a2',
#  'Gpd2',
#  'Ermn',
#  'Cytip',
#  'Gm13546',
#  'Acvr1',
#  'Pkp4',
#  'Tanc1',
#  'Wdsub1',
#  'Baz2b',
#  'March7',
#  'Ly75',
#  'Rbms1',
#  'Tank',
#  'Psmd14',
#  'Dpp4',
#  'Ifih1',
#  'Cobll1',
#  'Scn2a',
#  'Ttc21b',
#  'B3galt1',
#  'Stk39',
#  'Cers6',
#  'Spc25',
#  'Fastkd1',
#  'Ppig',
#  'Phospho2',
#  'Ssb',
#  'Mettl5',
#  'Ubr3',
#  'Gorasp2',
#  'Tlk1',
#  'Mettl8',
#  'Dcaf17',
#  'Dync1i2',
#  'Slc25a12',
#  'Hat1',
#  'Metap1d',
#  'Dlx2',
#  'Itga6',
#  'Pdk1',
#  'Rapgef4',
#  'Map3k20',
#  'Cdca7',
#  'Sp3',
#  'Sp3os',
#  'Ola1',
#  'Cir1',
#  'Scrn3',
#  'Gpr155',
#  'Wipf1',
#  'Chrna1',
#  'Atf2',
#  'Atp5g3',
#  'Lnpk',
#  'Hoxd8',
#  'Mtx2',
#  'Hnrnpa3',
#  'Nfe2l2',
#  'Agps',
#  'Rbm45',
#  'Osbpl6',
#  'Prkra',
#  'Fkbp7',
#  'Plekha3',
#  'Sestd1',
#  'Cwc22',
#  'Ube2e3',
#  'Itga4',
#  'Itprid2',
#  'Pde1a',
#  'Dnajc10',
#  'Nckap1',
#  'Dusp19',
#  'Nup35',
#  'Zc3h15',
#  'Itgav',
#  'Fam171b',
#  'Calcrl',
#  'Ctnnd1',
#  'Selenoh',
#  'Tmx2',
#  'Med19',
#  'Zdhhc5',
#  'Clp1',
#  'Serping1',
#  'Ube2l6',
#  'Timm10',
#  'Ssrp1',
#  'Tnks1bp1',
#  'Ptprj',
#  'Nup160',
#  'Fnbp4',
#  'Mtch2',
#  'C1qtnf4',
#  'Ndufs3',
#  'Ptpmt1',
#  'Celf1',
#  'Rapsn',
#  'Psmc3',
#  'Slc39a13',
#  'Spi1',
#  'Madd',
#  ...]

# %%
# Surface genes expressed in GBM treatment group
cell_surface_genes = match_surf(synonyms)
[gene for gene in gbm_genes if gene in cell_surface_genes]
# Out:
# ['H13', 'Rpn2', 'F3', 'Cad', 'Bst1', 'Met', 'Rpn1', 'Spn', 'Kitl']

# %% [markdown]
# ## lookup_gene tools

# %%
sorted_counter_dict('Cd44', data=data, proportion=True)
#     """Returns a dict of clusters and proportion of cells that express 'gene'"""
# Out:
# {'6_CTRL': 0.748062015503876,
#  '11_TREAT': 0.6666666666666666,
#  '8_CTRL': 0.6448362720403022,
#  '8_TREAT': 0.6397849462365591,
#  '9_CTRL': 0.6392914653784219,
#  '12_CTRL': 0.6203703703703703,
#  '24_CTRL': 0.6078431372549019,
#  '18_CTRL': 0.6039603960396039,
#  '2_CTRL': 0.5915119363395226,
#  '3_CTRL': 0.5892439594699922,
#  '26_TREAT': 0.5853658536585366,
#  '1_TREAT': 0.5683975432719152,
#  '2_TREAT': 0.5658852061438965,
#  '12_TREAT': 0.5444444444444444,
#  '21_TREAT': 0.5384615384615384,
#  '1_CTRL': 0.522331566994701,
#  '9_TREAT': 0.5221238938053098,
#  '18_TREAT': 0.5066079295154186,
#  '10_CTRL': 0.5,
#  '24_TREAT': 0.5,
#  '15_TREAT': 0.479020979020979,
#  '11_CTRL': 0.4725,
#  '21_CTRL': 0.46551724137931033,
#  '6_TREAT': 0.46153846153846156,
#  '0_CTRL': 0.4528149048197651,
#  '3_TREAT': 0.43859649122807015,
#  '10_TREAT': 0.41594202898550725,
#  '5_CTRL': 0.4020172910662824,
#  '17_TREAT': 0.4,
#  '0_TREAT': 0.39009661835748793,
#  '13_TREAT': 0.38016528925619836,
#  '14_TREAT': 0.3746397694524496,
#  '15_CTRL': 0.3644859813084112,
#  '17_CTRL': 0.3463855421686747,
#  '4_TREAT': 0.3433734939759036,
#  '5_TREAT': 0.33076923076923076,
#  '13_CTRL': 0.30446194225721784,
#  '16_CTRL': 0.28703703703703703,
#  '22_TREAT': 0.27485380116959063,
#  '26_CTRL': 0.25,
#  '4_CTRL': 0.23529411764705882,
#  '16_TREAT': 0.22388059701492538,
#  '14_CTRL': 0.21551724137931033,
#  '19_TREAT': 0.1794871794871795,
#  '20_CTRL': 0.16326530612244897,
#  '22_CTRL': 0.14285714285714285,
#  '20_TREAT': 0.14173228346456693,
#  '25_TREAT': 0.11363636363636363,
#  '25_CTRL': 0.1111111111111111,
#  '19_CTRL': 0.10638297872340426,
#  '7_CTRL': 0.07630522088353414,
#  '7_TREAT': 0.07091172214182344,
#  '23_TREAT': 0.040983606557377046}

# %%
lookup_gene(gene='Prom1', sure=True)
#     """By default, will see whether input gene is unique,
#         - if the input matches more than one gene in list, returns list of genes that match
#         - if the input doesn't match any gene in list, tells the user to try again
#         - if the input matches one gene in list, returns a pd.Series of clusters and expression levels

#         If counter=True,
#         - returns a dict of clusters ordered by how many cells are in each"""
# Out:
# {'25_TREAT': 0.6818181818181818,
#  '26_CTRL': 0.25,
#  '25_CTRL': 0.2222222222222222,
#  '3_TREAT': 0.03508771929824561,
#  '10_TREAT': 0.013043478260869565,
#  '16_TREAT': 0.007462686567164179,
#  '12_TREAT': 0.0022222222222222222,
#  '1_TREAT': 0.0011166945840312675,
#  '4_TREAT': 0.0008605851979345956}

# %%
lookup_gene(gene_list=['Prom1', 'Cd44', 'Hmgn1', 'Actb', 'Cd9', 'Sox2'], counter=True)
# Out:
# The genes and their most common clusters are:
# {'Prom1': '25_TREAT', 'Cd44': '6_CTRL', 'Hmgn1': '26_CTRL', 'Actb': '1_CTRL', 'Cd9': '22_CTRL', 'Sox2': '26_TREAT'}
#
# The most common cluster is 1_CTRL, followed by 22_CTRL, followed by 25_TREAT

# %% [markdown]
# ## plotting_tools tools

# %%
expression_distribution(gene='Sox2', cluster='6_CTRL')
#     '''Returns dict - keys are statistical concepts and dict-values are numerical values for those concepts'''
# Out:
# The expression distribution of Sox2 in cluster 6_CTRL:
# {'Median': 1.0,
#  'Mean': 1.4061135371179039,
#  'Std': 0.8126495590884275,
#  'High': 6,
#  'Low': 1,
#  'Pct of cells': 0.22189922480620156}

# %%
plot_expression_distribution(gene='Gsdme', cluster_num=6)
#     '''Returns plot of distribution of gene transcripts levels for 'gene' in 'cluster' 
#         Note - this function takes a cluster number (so it can plot the CTRL and TREAT)
#         as opposed to a particular cluster (e.g., '6_CTRL')'''
